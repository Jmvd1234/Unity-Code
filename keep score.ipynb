# %%
a_money = 0
b_money = 0
c_money = 0

a_resources = 0
b_resources= 0
c_resources = 0

while True:
    keep_playing = input("keep playing? ")
    if keep_playing == "no":
      break
    edit = input("Do you want to update money or resources? ")
    if edit == "money":
         moneys = input("Player A', B's, or C's money? ")
         if moneys == "A":
             print("How much money? ")
             addmoney = int(float(input()))
             a_money = a_money + addmoney
             print(f'Player A now has {a_money} money')
         elif moneys == "B":
             print("How much money? ")
             addmoney = int(float(input("")))
             b_money = b_money + addmoney
             print(f'Player B now has {b_money} money')
         elif moneys == "C":
             print("How much money? ")
             addmoney = int(float(input("")))
             c_money = c_money + addmoney
             print(f'Player C now has {c_money} money')
         else:
             continue
    elif edit == "resources":
        sauces = input("Player A's, B's, or C's resources? ")
        if sauces == "A":
             print("How much resources? ")
             addsauces = int(float(input("")))
             a_resources = a_resources + addsauces
             print(f'Player A now has {a_resources} resources')
        elif sauces == "B":
             print("How much resources? ")
             addsauces = int(float(input("")))
             b_resources = b_resources + addsauces
             print(f'Player B now has {b_resources} resources')
        elif sauces == "C":
             print("How much resources? ")
             addsauces = int(float(input("")))
             c_resources = c_resources + addsauces
             print(f'Player A now has {c_resources} resources')
        else:
              continue
    else:
        continue
# Out:
# keep playing? yes
# Do you want to update money or resources? no
# keep playing? no
